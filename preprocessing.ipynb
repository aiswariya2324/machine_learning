# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler as sc
from sklearn.cluster import DBSCAN

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd/content/drive/My Drive/Dataset
# Out:
# /content/drive/My Drive/Dataset

# %%
dataset = pd.read_csv('heart.csv')
dataset.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='object')

# %%
# inst =  dataset[['thalach','oldpeak']]
# X = np.array(inst)

# %%
inst = dataset[['RestingBP','Oldpeak']]
X = np.array(inst)

# %%
print(dataset)
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0      172              N      0.0       Up             0
# 1      156              N      1.0     Flat             1
# 2       98              N      0.0       Up             0
# 3      108              Y      1.5     Flat             1
# 4      122              N      0.0       Up             0
# ..     ...            ...      ...      ...           ...
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0
#
# [918 rows x 12 columns]

# %%
print(X.shape)
# Out:
# (918, 2)

# %%
from sklearn.preprocessing import StandardScaler as sc
scl = sc()

# %%
X = scl.fit_transform(inst)
print(X[:10])
# Out:
# [[ 0.41090889 -0.83243239]
#  [ 1.49175234  0.10566353]
#  [-0.12951283 -0.83243239]
#  [ 0.30282455  0.57471149]
#  [ 0.95133062 -0.83243239]
#  [-0.66993455 -0.83243239]
#  [-0.12951283 -0.83243239]
#  [-1.21035628 -0.83243239]
#  [ 0.41090889  0.57471149]
#  [-0.66993455 -0.83243239]]

# %%
import itertools

# %%
from sklearn.cluster import DBSCAN
dbs = DBSCAN(eps = 0.3, min_samples = 30)
dbs.fit(X)
l = dbs.labels_
print(l[:150])
print(X.shape)
X = X.reshape(3,612)
sns.scatterplot(X[0], X[1], c = 1)
# Out:
# [-1 -1 -1]
# (3, 612)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-aca0cba34b4a> in <cell line: 8>()
#       6 print(X.shape)
#       7 X = X.reshape(3,612)
# ----> 8 sns.scatterplot(X[0], X[1], c = 1)
#
# TypeError: scatterplot() takes from 0 to 1 positional arguments but 2 were given
